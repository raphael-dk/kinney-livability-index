# %%
import rent_framing

# %%
rent_df = rent_framing.Housing('data_sets/city_zori_sm_month.csv')

# %%
rent_df.get_data()
# Out:
#       RegionID  SizeRank         RegionName RegionType StateName State  \
# 0         6181         0           New York       city        NY    NY
# 1        12447         1        Los Angeles       city        CA    CA
# 2        39051         2            Houston       city        TX    TX
# 3        17426         3            Chicago       city        IL    IL
# 4         6915         4        San Antonio       city        TX    TX
# ...        ...       ...                ...        ...       ...   ...
# 3421     16007     20473          Surf City       city        NC    NC
# 3422      6384     21163  Palm Beach Shores       city        FL    FL
# 3423     50196     21560             Quogue       city        NY    NY
# 3424    124999     22469          Lake Hart       city        FL    FL
# 3425     46862     24288              Ogden       city        KS    KS
#
#                                         Metro          CountyName  \
# ...
